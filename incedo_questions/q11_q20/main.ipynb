# %% [markdown]
# # Main file to run all these methods
# ### for questions 11 to 20
# ### Importing all revelant modules

# %%
from q11_character_count import count_chars
from q12_squares_nums import square_odds
from q13_rotate_list import rotate_list
from q14_sort_dict import sort_dict
from q15_average_list import average_list
from q16_second_largest import second_largest
from q17_is_prime import is_prime
from q18_list_primes import list_primes

# %% [markdown]
# ---
# ### Question 11: Write a function that returns a dictionary of character counts in a string
# Example: count_chars("hello") → {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
input_str11 = input("Enter the input string ")
print(f"The {input_str11} has the following character counts\n: {count_chars(input_str11)}")
# Out:
# The hello has the following character counts
# : {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %% [markdown]
# ---
# ### Q12. Write a function that squares numbers in a list if they are odd, using a list comprehension with a conditional.
# Example: square_odds([1, 2, 3, 4] -> [1, 2, 9, 4])

# %%
input_list12 = [1, 2, 4, 5]
print (f"The {input_list12} has the following sqaure odds : {square_odds(input_list12)}")
# Out:
# The [1, 2, 4, 5] has the following sqaure odds : [1, 2, 4, 25]

# %% [markdown]
# ---
# ### Q13. Write a function that rotates a list to the right by k steps using slicing.
# Example: rotate_list([1, 2, 3, 4, 5], 2) -> [4, 5, 1, 2, 3]

# %%
input_list13 = [1, 2, 3, 4, 5, 6]
k = 4
print(f"\nInput is {input_list13}\nk is {k} \nOutput is :{rotate_list(input_list13, k)}")
# Out:
# Input is [1, 2, 3, 4, 5, 6]
# k is 4
# Output is :[3, 4, 5, 6, 1, 2, 3]

# %% [markdown]
# ---
# ### Q14. Write a function that takes a list of dictionaries and sorts it by the "name" key in ascending order
# Example:
# Input
# [
#     {"name": "Bob", "age": 25},
#     {"name":"Alice", "age": 30}
# ]
#
# Output
# [
#     {"name": "Alice", "age": 30},
#     {"name": "Bob", "age": 25}
# ]

# %%
# Q14. Write a function that takes a list of dictionaries and sorts it by the 
#      "name" key in ascending order

input_list14 = [{"name": "Bob", "age" : 25},
                {"name": "Alice", "age" : 30}]
print(f"The input list is {input_list14}")
print(f"The output sorted list is{sort_dict(input_list14)}")
# Out:
# The input list is [{'name': 'Bob', 'age': 25}, {'name': 'Alice', 'age': 30}]
# The output sorted list is[{'name': 'Alice', 'age': 30}, {'name': 'Bob', 'age': 25}]

# %% [markdown]
# ---
#
# ### 15. Write a function that takes a list of numbers and returns their arithmetic mean (return None for an empty list).
# Example: average_list([4, 8]) → 6.0

# %%
input_list15 = [1,2,3,4,5]
print(average_list(input_list15))
print(average_list())
# Out:
# 3
# None

# %% [markdown]
# ---
#
# ### 16. Write a function that returns the second-largest unique number in a list (raise an error if the list has fewer than two unique values).
# Example: second_largest([4, 1, 7, 7, 3]) → 4

# %%
input_list16 = [1,2,3,4,5]
print(second_largest(input_list16))
# Out:
# 4

# %% [markdown]
# ---
#
# ### 17. Write a function that checks whether an integer is prime.
# Example: is_prime(11) -> True

# %%
input_num = 6
print(f"{input_num} is a Prime number {is_prime(input_num)}")
# Out:
# 6 is a Prime number False

# %% [markdown]
# ---
#
# ### 18. Write a function that returns a list of all prime numbers less than or equal to a given limit.
# Example: list_primes(10) -> [2, 3, 5, 7]

# %%
input_num = 10
print(f"The list of primes until {input_num} is \n {list_primes(input_num)}")
# Out:
# The list of primes until 10 is
#  [2, 3, 5, 7]
