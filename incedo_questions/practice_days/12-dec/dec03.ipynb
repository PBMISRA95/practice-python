# %% [markdown]
# ## Practice Date - 03rd December 2025
# Repeating Question 7 and 8
# ---

# %% [markdown]
# ### Question 8 - Write a function that removes duplicates from a list and returns the result.
# Example - remove_duplicates([1, 2, 2, 3, 4, 4]) -> [1, 2, 3, 4]

# %%
input_list = [1, 2, 2, 3, 4, 4]

def remove_duplicates(input_list: list[int]) -> list[int]:
    output_list = []
    for num in input_list:
        if num in output_list:
            continue
        else:
            output_list.append(num) 
    return output_list

print(f"\n The given list {input_list} after removing duplicates is {remove_duplicates(input_list)} ")
# Out:
#  The given list [1, 2, 2, 3, 4, 4] after removing duplicates is [1, 2, 3, 4]

# %% [markdown]
# ### Q7. Write a function that checks if a string is a palindrome (case-insensitive)
# Example: is_palindrome("Racecar") -> True

# %%
input_str7 = "racecar"

def is_palindrome(input_str: str)-> bool:
    if input_str == input_str[::-1]:
        return True
    else:
        return False

print(f"{input_str7} is a Palindrome: {is_palindrome(input_str7)}")
# Out:
# racecar is a Palindrome: True
