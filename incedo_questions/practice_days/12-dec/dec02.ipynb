# %% [markdown]
# ## Practice Date - 02nd December 2025

# %%
num=6

# %%
# Q11: Write a function that returns a dictionary of character counts in a string.
# Example: count_chars("hello") -> {'h': 1, 'e': 1, 'l': 2, 'o': 1}

input_string = "hello"
def count_chars(input_str: str) -> dict:
    output_dict ={}
    for char in input_str:
        if char in output_dict:
            output_dict[char] +=1
        else:
            output_dict[char] = 1
    return output_dict

print(f"{str(input_string)} has the following count of chars {count_chars(input_string)}")
# Out:
# hello has the following count of chars {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
# Q9. Write a function that takes a string and returns a dictionary with the frequency of each word
# Example: word_frequency("the cat the dog") -> {"the": 2, "cat": 1, "dog": 1}

input_string = "Surya was the son of son of Rohan and the best person"

def word_frequency(input_str: str) -> dict:
    word_count = {}
    word = ""
    for char in input_str:
        if char == " ":
            if word in word_count:
                word_count[word] += 1
            else:
                word_count[word] = 1 
            word = ""
        else:
            word += char
    return word_count
            
print (f"The word count in the string {input_string} is \n {word_frequency(input_string)}")
# Out:
# The word count in the string Surya was the son of son of Rohan and the best person is
#  {'Surya': 1, 'was': 1, 'the': 2, 'son': 2, 'of': 2, 'Rohan': 1, 'and': 1, 'best': 1}
